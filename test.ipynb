# %%
YOUR_API_KEY = 'YXV0aDB8NjAyMDFmODYwOTQ5M2UwMDZhOGM4YjZhfDMxMjRjOTYyMGI'

# %%
from outscraper import ApiClient

api_client = ApiClient(api_key=YOUR_API_KEY)

# %%
places = api_client.google_maps_search('restaurants, Manhattan, NY, USA', limit=3)

places[0]
# Out:
# [{'query': 'restaurants, Manhattan, NY, USA',
#   'name': 'Marea',
#   'place_id': 'ChIJvWSDS_ZYwokRiG9D395loxo',
#   'google_id': '0x89c258f64b8364bd:0x1aa365dedf436f88',
#   'full_address': '240 Central Park S, New York, NY 10019',
#   'borough': 'Manhattan',
#   'street': '240 Central Park S',
#   'postal_code': '10019',
#   'area_service': False,
#   'country_code': 'US',
#   'country': 'United States of America',
#   'city': 'New York',
#   'us_state': 'New York',
#   'state': 'New York',
#   'plus_code': None,
#   'latitude': 40.7674251,
#   'longitude': -73.9811137,
#   'time_zone': 'America/New_York',
#   'popular_times': None,
#   'site': 'https://www.marearestaurant.com/new-york?utm_source=GoogleBusinessProfile&utm_medium=Website&utm_campaign=MapLabs',
#   'phone': '+1 212-582-5100',
#   'type': 'Seafood restaurant',
#   'logo': 'https://lh5.googleusercontent.com/-fzmCteXOC7w/AAAAAAAAAAI/AAAAAAAAAAA/bE_uUDOsRJA/s44-p-k-no-ns-nd/photo.jpg',
#   'description': 'High-end Italian seafood & housemade pastas in a chic Central Park South setting.',
#   'located_in': None,
#   'located_google_id': None,
#   'category': 'restaurants',
#   'subtypes': 'Seafood restaurant, Cocktail bar, Fine dining restaurant, Italian restaurant, Lunch restaurant, Takeout Restaurant, Restaurant, Wine bar',
#   'posts': None,
#   'reviews_tags': None,
#   'rating': 4.5,
#   'reviews': 2349,
#   'photos_count': 5175,
#   'cid': '1919489874092846984',
#   'reviews_link': 'https://search.google.com/local/reviews?placeid=ChIJvWSDS_ZYwokRiG9D395loxo&q=restaurants,+Manhattan,+NY,+USA&authuser=0&hl=en&gl=US',
#   'reviews_id': '1919489874092846984',
#   'photo': 'https://lh5.googleusercontent.com/p/AF1QipMzf9adSOMQkiRRf8Kw6YnfpC8H_glR9wpKAqnn=w800-h500-k-no',
#   'street_view': 'https://lh5.googleusercontent.com/p/AF1QipMzf9adSOMQkiRRf8Kw6YnfpC8H_glR9wpKAqnn=w1600-h1000-k-no',
#   'working_hours_old_format': 'Monday: 12-2:45\u202fPM,5-10\u202fPM | Tuesday: 12-2:45\u202fPM,5-10\u202fPM | Wednesday: 12-2:45\u202fPM,5-10\u202fPM | Thursday: 12-2:45\u202fPM,5-10\u202fPM | Friday: 12-2:45\u202fPM,5-11\u202fPM | Saturday: 12-2:45\u202fPM,5-11\u202fPM | Sunday: 12-2:45\u202fPM,5-10\u202fPM',
#   'working_hours': {'Monday': '12-2:45\u202fPM,5-10\u202fPM',
#    'Tuesday': '12-2:45\u202fPM,5-10\u202fPM',
#    'Wednesday': '12-2:45\u202fPM,5-10\u202fPM',
#    'Thursday': '12-2:45\u202fPM,5-10\u202fPM',
#    'Friday': '12-2:45\u202fPM,5-11\u202fPM',
#    'Saturday': '12-2:45\u202fPM,5-11\u202fPM',
#    'Sunday': '12-2:45\u202fPM,5-10\u202fPM'},
#   'other_hours': [{'delivery': {'Monday': '5-8:45\u202fPM',
#      'Tuesday': '5-8:45\u202fPM',
#      'Wednesday': '5-8:45\u202fPM',
#      'Thursday': '5-8:45\u202fPM',
#      'Friday': '5-8:45\u202fPM',
#      'Saturday': '5-8:45\u202fPM',
#      'Sunday': '5-8:45\u202fPM'}},
#    {'takeout': {'Monday': '5-8:45\u202fPM',
#      'Tuesday': '5-8:45\u202fPM',
#      'Wednesday': '5-8:45\u202fPM',
#      'Thursday': '5-8:45\u202fPM',
#      'Friday': '5-8:45\u202fPM',
#      'Saturday': '5-8:45\u202fPM',
#      'Sunday': '5-8:45\u202fPM'}},
#    {'lunch': {'Monday': '12-2:45\u202fPM',
#      'Tuesday': '12-2:45\u202fPM',
#      'Wednesday': '12-2:45\u202fPM',
#      'Thursday': '12-2:45\u202fPM',
#      'Friday': '12-2:45\u202fPM',
#      'Saturday': '12-2:45\u202fPM',
#      'Sunday': '12-2:45\u202fPM'}},
#    {'dinner': {'Monday': '5-10\u202fPM',
#      'Tuesday': '5-10\u202fPM',
#      'Wednesday': '5-10\u202fPM',
#      'Thursday': '5-10\u202fPM',
#      'Friday': '5-11\u202fPM',
#      'Saturday': '5-11\u202fPM',
#      'Sunday': '5-10\u202fPM'}},
#    {'kitchen': {'Monday': '12-3\u202fPM,5-10\u202fPM',
#      'Tuesday': '12-3\u202fPM,5-10\u202fPM',
#      'Wednesday': '12-3\u202fPM,5-10\u202fPM',
#      'Thursday': '12-3\u202fPM,5-10\u202fPM',
#      'Friday': '12-3\u202fPM,5-11\u202fPM',
#      'Saturday': '12-3\u202fPM,5-11\u202fPM',
#      'Sunday': '12-3\u202fPM,5-10\u202fPM'}}],
#   'business_status': 'OPERATIONAL',
#   'about': {'Service options': {'Outdoor seating': True,
#     'No-contact delivery': True,
#     'Delivery': True,
#     'Takeout': True,
#     'Dine-in': True},
#    'Highlights': {'Great coffee': True, 'Great dessert': True},
#    'Popular for': {'Lunch': True, 'Dinner': True, 'Solo dining': True},
#    'Accessibility': {'Wheelchair accessible entrance': True,
#     'Wheelchair accessible restroom': True,
#     'Wheelchair accessible seating': True},
#    'Offerings': {'Alcohol': True,
#     'Beer': True,
#     'Cocktails': True,
#     'Coffee': True,
#     'Hard liquor': True,
#     'Healthy options': True,
#     'Vegetarian options': True,
#     'Wine': True},
#    'Dining options': {'Brunch': True,
#     'Lunch': True,
#     'Dinner': True,
#     'Dessert': True,
#     'Seating': True},
#    'Amenities': {'Bar onsite': True, 'High chairs': True, 'Restroom': True},
#    'Atmosphere': {'Cozy': True, 'Romantic': True, 'Upscale': True},
#    'Crowd': {'Family-friendly': True,
#     'Groups': True,
#     'LGBTQ+ friendly': True,
#     'Tourists': True,
#     'Transgender safespace': True},
#    'Planning': {'Lunch reservations recommended': True,
#     'Reservations required': True,
#     'Dinner reservations recommended': True,
#     'Accepts reservations': True,
#     'Usually a wait': True},
#    'Payments': {'Debit cards': True},
#    'Other': {'LGBTQ+ friendly': True}},
#   'range': '$$$$',
#   'reviews_per_score': {'1': 82, '2': 49, '3': 137, '4': 353, '5': 1728},
#   'reservation_links': ['https://www.sevenrooms.com/reservations/marea?utm_source=GoogleBusinessProfile&utm_medium=Reservations&utm_campaign=MapLabs'],
#   'booking_appointment_link': 'https://www.sevenrooms.com/reservations/marea?utm_source=GoogleBusinessProfile&utm_medium=Reservations&utm_campaign=MapLabs',
#   'menu_link': None,
#   'order_links': ['https://www.sevenrooms.com/reservations/marea?utm_source=GoogleBusinessProfile&utm_medium=Reservations&utm_campaign=MapLabs'],
#   'owner_id': '115088230679165187897',
#   'verified': True,
#   'owner_title': 'Marea',
#   'owner_link': 'https://www.google.com/maps/contrib/115088230679165187897',
#   'location_link': 'https://www.google.com/maps/place/Marea/@40.7674251,-73.9811137,14z/data=!4m8!1m2!2m1!1sMarea!3m4!1s0x89c258f64b8364bd:0x1aa365dedf436f88!8m2!3d40.7674251!4d-73.9811137'},
#  {'query': 'restaurants, Manhattan, NY, USA',
#   'name': 'The Smith',
#   'place_id': 'ChIJbd5El_VYwokRFEtA5j2r7Ls',
#   'google_id': '0x89c258f59744de6d:0xbbecab3de6404b14',
#   'full_address': '1900 Broadway, New York, NY 10023',
#   'borough': 'Manhattan',
#   'street': '1900 Broadway',
#   'postal_code': '10023',
#   'area_service': False,
#   'country_code': 'US',
#   'country': 'United States of America',
#   'city': 'New York',
#   'us_state': 'New York',
#   'state': 'New York',
#   'plus_code': None,
#   'latitude': 40.7716564,
#   'longitude': -73.98164009999999,
#   'time_zone': 'America/New_York',
#   'popular_times': None,
#   'site': 'https://thesmithrestaurant.com/',
#   'phone': '+1 212-496-5700',
#   'type': 'American restaurant',
#   'logo': 'https://lh4.googleusercontent.com/-fqfbzlCALtQ/AAAAAAAAAAI/AAAAAAAAAAA/5juorAHeJbk/s44-p-k-no-ns-nd/photo.jpg',
#   'description': 'Lively place for classic American fare & specialty cocktails in spacious digs with a hopping bar.',
#   'located_in': None,
#   'located_google_id': None,
#   'category': 'restaurants',
#   'subtypes': 'American restaurant, Breakfast restaurant, Brunch restaurant, Oyster bar restaurant',
#   'posts': None,
#   'reviews_tags': None,
#   'rating': 4.4,
#   'reviews': 4147,
#   'photos_count': 3221,
#   'cid': '13541386461940566804',
#   'reviews_link': 'https://search.google.com/local/reviews?placeid=ChIJbd5El_VYwokRFEtA5j2r7Ls&q=restaurants,+Manhattan,+NY,+USA&authuser=0&hl=en&gl=US',
#   'reviews_id': '-4905357611768984812',
#   'photo': 'https://lh5.googleusercontent.com/p/AF1QipNe2dF6iDgYMx6tSR_OlCetjX-IbbsMzrFzVxcI=w800-h500-k-no',
#   'street_view': 'https://lh5.googleusercontent.com/p/AF1QipNe2dF6iDgYMx6tSR_OlCetjX-IbbsMzrFzVxcI=w1600-h1000-k-no',
#   'working_hours_old_format': 'Monday: 8\u202fAM-11\u202fPM | Tuesday: 8\u202fAM-12\u202fAM | Wednesday: 8\u202fAM-12\u202fAM | Thursday: 8\u202fAM-12\u202fAM | Friday: 8\u202fAM-12\u202fAM | Saturday: 9\u202fAM-12\u202fAM | Sunday: 9\u202fAM-11\u202fPM',
#   'working_hours': {'Monday': '8\u202fAM-11\u202fPM',
#    'Tuesday': '8\u202fAM-12\u202fAM',
#    'Wednesday': '8\u202fAM-12\u202fAM',
#    'Thursday': '8\u202fAM-12\u202fAM',
#    'Friday': '8\u202fAM-12\u202fAM',
#    'Saturday': '9\u202fAM-12\u202fAM',
#    'Sunday': '9\u202fAM-11\u202fPM'},
#   'other_hours': [{'brunch': {'Monday': 'Closed',
#      'Tuesday': 'Closed',
#      'Wednesday': 'Closed',
#      'Thursday': 'Closed',
#      'Friday': 'Closed',
#      'Saturday': '9\u202fAM-4\u202fPM',
#      'Sunday': '9\u202fAM-4\u202fPM'}}],
#   'business_status': 'OPERATIONAL',
#   'about': {'Service options': {'Outdoor seating': True,
#     'Curbside pickup': True,
#     'Delivery': True,
#     'Takeout': True,
#     'Dine-in': True},
#    'Highlights': {'Fast service': True,
#     'Great cocktails': True,
#     'Great coffee': True,
#     'Great dessert': True},
#    'Popular for': {'Breakfast': True,
#     'Lunch': True,
#     'Dinner': True,
#     'Solo dining': True},
#    'Accessibility': {'Wheelchair accessible elevator': True,
#     'Wheelchair accessible entrance': True,
#     'Wheelchair accessible restroom': True,
#     'Wheelchair accessible seating': True},
#    'Offerings': {'Alcohol': True,
#     'Beer': True,
#     'Cocktails': True,
#     'Coffee': True,
#     'Comfort food': True,
#     'Happy hour drinks': True,
#     'Happy hour food': True,
#     'Hard liquor': True,
#     'Healthy options': True,
#     "Kids' menu": True,
#     'Late-night food': True,
#     'Organic dishes': True,
#     'Quick bite': True,
#     'Small plates': True,
#     'Vegetarian options': True,
#     'Wine': True},
#    'Dining options': {'Breakfast': True,
#     'Brunch': True,
#     'Lunch': True,
#     'Dinner': True,
#     'Dessert': True,
#     'Seating': True},
#    'Amenities': {'Bar onsite': True,
#     'Good for kids': True,
#     'High chairs': True,
#     'Restroom': True,
#     'Wi-Fi': True},
#    'Atmosphere': {'Casual': True, 'Cozy': True},
#    'Crowd': {'Family-friendly': True, 'Groups': True, 'Tourists': True},
#    'Planning': {'Lunch reservations recommended': True,
#     'Dinner reservations recommended': True,
#     'Accepts reservations': True,
#     'Usually a wait': True},
#    'Payments': {'NFC mobile payments': True}},
#   'range': '$$',
#   'reviews_per_score': {'1': 104, '2': 97, '3': 331, '4': 1268, '5': 2347},
#   'reservation_links': ['https://thesmithrestaurant.com/location/lincoln-square/',
#    'https://www.opentable.com/restaurant/profile/98185?ref=1068'],
#   'booking_appointment_link': 'https://thesmithrestaurant.com/location/lincoln-square/',
#   'menu_link': None,
#   'order_links': ['https://thesmithrestaurant.com/location/lincoln-square/',
#    'https://www.opentable.com/restaurant/profile/98185?ref=1068'],
#   'owner_id': '103162007826525695972',
#   'verified': True,
#   'owner_title': 'The Smith',
#   'owner_link': 'https://www.google.com/maps/contrib/103162007826525695972',
#   'location_link': 'https://www.google.com/maps/place/The+Smith/@40.7716564,-73.98164009999999,14z/data=!4m8!1m2!2m1!1sThe+Smith!3m4!1s0x89c258f59744de6d:0xbbecab3de6404b14!8m2!3d40.7716564!4d-73.98164009999999'},
#  {'query': 'restaurants, Manhattan, NY, USA',
#   'name': 'Upland',
#   'place_id': 'ChIJWVD7FadZwokRs_pS6XY7VOU',
#   'google_id': '0x89c259a715fb5059:0xe5543b76e952fab3',
#   'full_address': '345 Park Ave S, New York, NY 10010',
#   'borough': 'Manhattan',
#   'street': '345 Park Ave S',
#   'postal_code': '10010',
#   'area_service': False,
#   'country_code': 'US',
#   'country': 'United States of America',
#   'city': 'New York',
#   'us_state': 'New York',
#   'state': 'New York',
#   'plus_code': None,
#   'latitude': 40.7419313,
#   'longitude': -73.984644,
#   'time_zone': 'America/New_York',
#   'popular_times': None,
#   'site': 'https://uplandnyc.com/?utm_source=Google+My+Business&utm_medium=Website+Button',
#   'phone': '+1 212-686-1006',
#   'type': 'Californian restaurant',
#   'logo': 'https://lh4.googleusercontent.com/-zvSnhN_Mek4/AAAAAAAAAAI/AAAAAAAAAAA/XHbA606mawk/s44-p-k-no-ns-nd/photo.jpg',
#   'description': 'Spacious, casually chic brasserie with hearty dishes featuring Californian & Italian influences.',
#   'located_in': None,
#   'located_google_id': None,
#   'category': 'Californian restaurant',
#   'subtypes': 'Californian restaurant, American restaurant, Bar, Italian restaurant, Takeout Restaurant, Restaurant',
#   'posts': None,
#   'reviews_tags': None,
#   'rating': 4.5,
#   'reviews': 1792,
#   'photos_count': 4313,
#   'cid': '16524898314635901619',
#   'reviews_link': 'https://search.google.com/local/reviews?placeid=ChIJWVD7FadZwokRs_pS6XY7VOU&q=restaurants,+Manhattan,+NY,+USA&authuser=0&hl=en&gl=US',
#   'reviews_id': '-1921845759073649997',
#   'photo': 'https://lh5.googleusercontent.com/p/AF1QipPFzGn4Ie2huHtDmrAmxl0GkSIp5rrXipoxPF55=w800-h500-k-no',
#   'street_view': 'https://lh5.googleusercontent.com/p/AF1QipPFzGn4Ie2huHtDmrAmxl0GkSIp5rrXipoxPF55=w1600-h1000-k-no',
#   'working_hours_old_format': 'Monday: 11:30\u202fAM-3\u202fPM,5-10\u202fPM | Tuesday: 11:30\u202fAM-3\u202fPM,5-10\u202fPM | Wednesday: 11:30\u202fAM-3\u202fPM,5-10\u202fPM | Thursday: 11:30\u202fAM-3\u202fPM,5-10\u202fPM | Friday: 11:30\u202fAM-3\u202fPM,5-11\u202fPM | Saturday: 10\u202fAM-3\u202fPM,5-11\u202fPM | Sunday: 10\u202fAM-3\u202fPM,5-9\u202fPM',
#   'working_hours': {'Monday': '11:30\u202fAM-3\u202fPM,5-10\u202fPM',
#    'Tuesday': '11:30\u202fAM-3\u202fPM,5-10\u202fPM',
#    'Wednesday': '11:30\u202fAM-3\u202fPM,5-10\u202fPM',
#    'Thursday': '11:30\u202fAM-3\u202fPM,5-10\u202fPM',
#    'Friday': '11:30\u202fAM-3\u202fPM,5-11\u202fPM',
#    'Saturday': '10\u202fAM-3\u202fPM,5-11\u202fPM',
#    'Sunday': '10\u202fAM-3\u202fPM,5-9\u202fPM'},
#   'other_hours': [{'lunch': {'Monday': '11:30\u202fAM-3\u202fPM',
#      'Tuesday': '11:30\u202fAM-3\u202fPM',
#      'Wednesday': '11:30\u202fAM-3\u202fPM',
#      'Thursday': '11:30\u202fAM-3\u202fPM',
#      'Friday': '11:30\u202fAM-3\u202fPM',
#      'Saturday': 'Closed',
#      'Sunday': 'Closed'}},
#    {'dinner': {'Monday': '5-10\u202fPM',
#      'Tuesday': '5-10\u202fPM',
#      'Wednesday': '5-10\u202fPM',
#      'Thursday': '5-10\u202fPM',
#      'Friday': '5-10\u202fPM',
#      'Saturday': '5-10\u202fPM',
#      'Sunday': '5-9\u202fPM'}},
#    {'delivery': {'Monday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Tuesday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Wednesday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Thursday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Friday': 'Closed',
#      'Saturday': 'Closed',
#      'Sunday': '11\u202fAM-3\u202fPM,5-10\u202fPM'}},
#    {'takeout': {'Monday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Tuesday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Wednesday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Thursday': '11:30\u202fAM-3:30\u202fPM,5-10\u202fPM',
#      'Friday': 'Closed',
#      'Saturday': 'Closed',
#      'Sunday': '11\u202fAM-3\u202fPM,5-10\u202fPM'}},
#    {'brunch': {'Monday': 'Closed',
#      'Tuesday': 'Closed',
#      'Wednesday': 'Closed',
#      'Thursday': 'Closed',
#      'Friday': 'Closed',
#      'Saturday': '10\u202fAM-3\u202fPM',
#      'Sunday': '10\u202fAM-3\u202fPM'}}],
#   'business_status': 'OPERATIONAL',
#   'about': {'Service options': {'Delivery': True,
#     'Takeout': True,
#     'Dine-in': True},
#    'Highlights': {'Great coffee': True,
#     'Great dessert': True,
#     'Great tea selection': True},
#    'Popular for': {'Lunch': True, 'Dinner': True, 'Solo dining': True},
#    'Accessibility': {'Wheelchair accessible entrance': True,
#     'Wheelchair accessible restroom': True,
#     'Wheelchair accessible seating': True,
#     'Wheelchair accessible parking lot': False},
#    'Offerings': {'Alcohol': True,
#     'Beer': True,
#     'Cocktails': True,
#     'Coffee': True,
#     'Comfort food': True,
#     'Hard liquor': True,
#     'Healthy options': True,
#     'Late-night food': True,
#     'Small plates': True,
#     'Vegetarian options': True,
#     'Wine': True},
#    'Dining options': {'Brunch': True,
#     'Lunch': True,
#     'Dinner': True,
#     'Dessert': True,
#     'Seating': True},
#    'Amenities': {'Bar onsite': True,
#     'High chairs': True,
#     'Restroom': True,
#     'Wi-Fi': True},
#    'Atmosphere': {'Romantic': True, 'Upscale': True},
#    'Crowd': {'Family-friendly': True,
#     'Groups': True,
#     'LGBTQ+ friendly': True,
#     'Tourists': True,
#     'Transgender safespace': True},
#    'Planning': {'Lunch reservations recommended': True,
#     'Dinner reservations recommended': True,
#     'Accepts reservations': True,
#     'Usually a wait': True},
#    'Payments': {'Debit cards': True, 'Credit cards': True},
#    'Other': {'LGBTQ+ friendly': True}},
#   'range': '$$$',
#   'reviews_per_score': {'1': 51, '2': 37, '3': 115, '4': 397, '5': 1192},
#   'reservation_links': ['https://resy.com/cities/ny/upland',
#    'https://uplandnyc.com/?utm_source=Google%20My%20Business&utm_medium=Reservation%20Button'],
#   'booking_appointment_link': 'https://resy.com/cities/ny/upland',
#   'menu_link': None,
#   'order_links': ['https://resy.com/cities/ny/upland',
#    'https://uplandnyc.com/?utm_source=Google%20My%20Business&utm_medium=Reservation%20Button'],
#   'owner_id': '111762591187585073824',
#   'verified': True,
#   'owner_title': 'Upland',
#   'owner_link': 'https://www.google.com/maps/contrib/111762591187585073824',
#   'location_link': 'https://www.google.com/maps/place/Upland/@40.7419313,-73.984644,14z/data=!4m8!1m2!2m1!1sUpland!3m4!1s0x89c259a715fb5059:0xe5543b76e952fab3!8m2!3d40.7419313!4d-73.984644'}]

# %%
reviews = api_client.google_maps_reviews(places[0][0]['place_id'], reviews_limit=3)

reviews[0]['reviews_data'][2]
# Out:
# {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNtOV9qcWFBEAE',
#  'author_link': 'https://www.google.com/maps/contrib/111564944263993077278?hl=en-US',
#  'author_title': 'Austin',
#  'author_id': '111564944263993077278',
#  'author_image': 'https://lh3.googleusercontent.com/a/AGNmyxZHV540LtqEYf1V-UBJJOxjOl0SGoiCUBFui8UY=s120-c-c0x00000000-cc-rp-mo-ba5-br100',
#  'review_text': 'Amazing service. Brought our own bottle for a birthday dinner as well as our own cake. Everything from entering the restaurant to leaving was exquisite, service wise. We ordered the lobster, oysters and octopus for our appetizers, and several other mains for a table of 2. Some dishes have a slightly saltier/heavier taste than we are accustomed to, but it was still delicious. Our waiter was great and the maitre d is always helpful with our requests.',
#  'review_img_url': 'https://lh5.googleusercontent.com/p/AF1QipOqb1bS2VncGh-mwI5WRdO9PzwphBCocb0UuoPk',
#  'review_img_urls': ['https://lh5.googleusercontent.com/p/AF1QipOqb1bS2VncGh-mwI5WRdO9PzwphBCocb0UuoPk',
#   'https://lh5.googleusercontent.com/p/AF1QipNr92OcqmsCdpaNPXxOvMkJ6HMoqvCyLs1Trp3b',
#   'https://lh5.googleusercontent.com/p/AF1QipOHukq8mFvYkz4XywIk1FK9XhWbV_ePvKaas-lj',
#   'https://lh5.googleusercontent.com/p/AF1QipPe9rSMLE7dkGOX4bMB2SdIoT4RTzKWD2prnwQE'],
#  'owner_answer': 'Thank you for your kind words Austin. We enjoy being able to provide you with a 5-star experience! The Marea team is looking forward to welcoming you back in the near future.',
#  'owner_answer_timestamp': 1653438611,
#  'owner_answer_timestamp_datetime_utc': '05/25/2022 00:30:11',
#  'review_link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNtOV9qcWFBEAE!2m1!1s0x0:0x1aa365dedf436f88!3m1!1s2@1:CIHM0ogKEICAgICm9_jqaA%7CCgwIgI6EjwYQuIvxrAE%7C?hl=en-US',
#  'review_rating': 5,
#  'review_timestamp': 1642137344,
#  'review_datetime_utc': '01/14/2022 05:15:44',
#  'review_likes': 7}
